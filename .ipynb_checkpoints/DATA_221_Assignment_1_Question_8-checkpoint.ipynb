# %%
import pandas as pd

data = {
"A": [1, 2, 2, 1],
"B": [3.1, 4.2, 1.5, 6.3],
"C": [800, 150, 400, 210]
}
    
data_frame = pd.DataFrame(data)

data_frame["D"] = data_frame["C"] / (data_frame["A"] + data_frame["B"])

print(data_frame)
# Out:
#    A    B    C           D
# 0  1  3.1  800  195.121951
# 1  2  4.2  150   24.193548
# 2  2  1.5  400  114.285714
# 3  1  6.3  210   28.767123
